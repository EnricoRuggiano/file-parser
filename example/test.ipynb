# %%
from file_parser import FileParser
p = FileParser()
p
# Out:
# {'input_path': '', 'output_path': '', 'raw_content': '', 'format': '', 'parsed_content': ''}

# %% [markdown]
# ### RAW

# %%
p.read('sample.txt')
res = p.parse('raw')
res
# Out:
# {'value': 'ehila manson, come va?', 'format': 'raw'}

# %% [markdown]
# ### JSON

# %%
p.read('sample.json')
res = p.parse('json')
res
# Out:
# {'1': 'this is something', 'two': 2, 'hello': 'ehila manson!', 'mnnn': None}

# %% [markdown]
# ### INI

# %%
from file_parser import FileParser
p = FileParser()
p.read('sample.ini')
res = p.parse('ini')
res
# Out:
# {'DEVICE1': {'usethesedomainsizes': '1',
#   'usecounts': '0',
#   'onecoilwrite': '0',
#   'oneregwrite': '0',
#   'conservesconn': '1',
#   'connsecondary': '0',
#   'coils': '65535',
#   'disc inputs': '65535',
#   'input reg.': '65535',
#   'holding reg.': '65535',
#   'gen ref file1': '0',
#   'gen ref file2': '0',
#   'gen ref file3': '0',
#   'gen ref file4': '0',
#   'gen ref file5': '0',
#   'gen ref file6': '0',
#   'gen ref file7': '0',
#   'gen ref file8': '0',
#   'gen ref file9': '0',
#   'gen ref file10': '0',
#   'dp_input reg.': '0',
#   'dp_holding reg.': '0'},
#  'DEVICE2': {'usethesedomainsizes': '1',
#   'usecounts': '0',
#   'onecoilwrite': '0',
#   'oneregwrite': '0',
#   'conservesconn': '1',
#   'connsecondary': '0',
#   'coils': '65535',
#   'disc inputs': '65535',
#   'input reg.': '65535',
#   'holding reg.': '65535',
#   'gen ref file1': '0',
#   'gen ref file2': '0',
#   'gen ref file3': '0',
#   'gen ref file4': '0',
#   'gen ref file5': '0',
#   'gen ref file6': '0',
#   'gen ref file7': '0',
#   'gen ref file8': '0',
#   'gen ref file9': '0',
#   'gen ref file10': '0',
#   'dp_input reg.': '0',
#   'dp_holding reg.': '0'}}

# %% [markdown]
# ### CSV

# %%
from file_parser import FileParser
p = FileParser()
p.read('sample.csv')
res = p.parse('csv')
res
# Out:
# [{'Username': 'booker12',
#   ' Identifier': '9012',
#   'First name': 'Rachel',
#   'Last name': 'Booker'},
#  {'Username': 'grey07',
#   ' Identifier': '2070',
#   'First name': 'Laura',
#   'Last name': 'Grey'},
#  {'Username': 'johnson81',
#   ' Identifier': '4081',
#   'First name': 'Craig',
#   'Last name': 'Johnson'},
#  {'Username': 'jenkins46',
#   ' Identifier': '9346',
#   'First name': 'Mary',
#   'Last name': 'Jenkins'},
#  {'Username': 'smith79',
#   ' Identifier': '5079',
#   'First name': 'Jamie',
#   'Last name': 'Smith'}]

# %% [markdown]
# ### XLSX

# %%
from file_parser import FileParser
p = FileParser()
p.read('sample.xlsx')
res = p.parse('xlsx')
res
# Out:
# Warning: input file not utf-8. Using bytes
# [{'Username': 'booker12',
#   'Identifier': '9012',
#   'First name': 'Rachel',
#   'Last name': 'Booker'},
#  {'Username': 'grey07',
#   'Identifier': '2070',
#   'First name': 'Laura',
#   'Last name': 'Grey'},
#  {'Username': 'johnson81',
#   'Identifier': '4081',
#   'First name': 'Craig',
#   'Last name': 'Johnson'},
#  {'Username': 'jenkins46',
#   'Identifier': '9346',
#   'First name': 'Mary',
#   'Last name': 'Jenkins'}]

# %%
p.raw_content
# Out:
# b'PK\x03\x04\x14\x00\x08\x08\x08\x00\x18>\xb2V\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x1a\x00\x00\x